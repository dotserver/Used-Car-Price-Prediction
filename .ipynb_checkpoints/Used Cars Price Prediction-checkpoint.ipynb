# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
df = pd.read_csv("all_cars_merged.csv")
df.head()
# Out:
#    Unnamed: 0  model  year  price  mileage  tax   mpg  engineSize  Diesel  \
# 0           0   GT86  2016  16000    24089  265  36.2         2.0       0
# 1           1   GT86  2017  15995    18615  145  36.2         2.0       0
# 2           2   GT86  2015  13998    27469  265  36.2         2.0       0
# 3           3   GT86  2017  18998    14736  150  36.2         2.0       0
# 4           4   GT86  2017  17498    36284  145  36.2         2.0       0
#
#    Electric  ...  Petrol  Automatic  Manual  Other.1  Semi-Auto  Audi  BMW  \
# 0         0  ...       1          0       1        0          0     0    0
# 1         0  ...       1          0       1        0          0     0    0
# 2         0  ...       1          0       1        0          0     0    0
# 3         0  ...       1          0       1        0          0     0    0
# 4         0  ...       1          0       1        0          0     0    0
#
#    Hyundai  Mercedes  Toyota
# 0        0         0       1
# 1        0         0       1
# 2        0         0       1
# 3        0         0       1
# 4        0         0       1
#
# [5 rows x 22 columns]

# %%
df.drop(columns="Unnamed: 0",inplace=True)
df.head()
# Out:
#    model  year  price  mileage  tax   mpg  engineSize  Diesel  Electric  \
# 0   GT86  2016  16000    24089  265  36.2         2.0       0         0
# 1   GT86  2017  15995    18615  145  36.2         2.0       0         0
# 2   GT86  2015  13998    27469  265  36.2         2.0       0         0
# 3   GT86  2017  18998    14736  150  36.2         2.0       0         0
# 4   GT86  2017  17498    36284  145  36.2         2.0       0         0
#
#    Hybrid  ...  Petrol  Automatic  Manual  Other.1  Semi-Auto  Audi  BMW  \
# 0       0  ...       1          0       1        0          0     0    0
# 1       0  ...       1          0       1        0          0     0    0
# 2       0  ...       1          0       1        0          0     0    0
# 3       0  ...       1          0       1        0          0     0    0
# 4       0  ...       1          0       1        0          0     0    0
#
#    Hyundai  Mercedes  Toyota
# 0        0         0       1
# 1        0         0       1
# 2        0         0       1
# 3        0         0       1
# 4        0         0       1
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#            model  year  price  mileage  tax   mpg  engineSize  Diesel  \
# 46161         X3  2016  19000    40818  150  54.3         2.0       1
# 46162   5 Series  2016  14600    42947  125  60.1         2.0       1
# 46163   3 Series  2017  13100    25468  200  42.8         2.0       0
# 46164   1 Series  2014   9930    45000   30  64.2         2.0       1
# 46165         X1  2017  15981    59432  125  57.6         2.0       1
#
#        Electric  Hybrid  ...  Petrol  Automatic  Manual  Other.1  Semi-Auto  \
# 46161         0       0  ...       0          1       0        0          0
# 46162         0       0  ...       0          1       0        0          0
# 46163         0       0  ...       1          0       1        0          0
# 46164         0       0  ...       0          1       0        0          0
# 46165         0       0  ...       0          1       0        0          0
#
#        Audi  BMW  Hyundai  Mercedes  Toyota
# 46161     0    1        0         0       0
# 46162     0    1        0         0       0
# 46163     0    1        0         0       0
# 46164     0    1        0         0       0
# 46165     0    1        0         0       0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Data Cleaning

# %%
df['model'] = df['model'].apply(lambda x:x.strip())

# %%
df.shape
# Out:
# (46166, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46166 entries, 0 to 46165
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   model       46166 non-null  object
#  1   year        46166 non-null  int64
#  2   price       46166 non-null  int64
#  3   mileage     46166 non-null  int64
#  4   tax         46166 non-null  int64
#  5   mpg         46166 non-null  float64
#  6   engineSize  46166 non-null  float64
#  7   Diesel      46166 non-null  int64
#  8   Electric    46166 non-null  int64
#  9   Hybrid      46166 non-null  int64
#  10  Other       46166 non-null  int64
#  11  Petrol      46166 non-null  int64
#  12  Automatic   46166 non-null  int64
#  13  Manual      46166 non-null  int64
#  14  Other.1     46166 non-null  int64
#  15  Semi-Auto   46166 non-null  int64
#  16  Audi        46166 non-null  int64
#  17  BMW         46166 non-null  int64
#  18  Hyundai     46166 non-null  int64
#  19  Mercedes    46166 non-null  int64
#  20  Toyota      46166 non-null  int64
# dtypes: float64(2), int64(18), object(1)
# memory usage: 7.4+ MB

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  46166.000000   46166.000000   46166.000000  46166.000000  46166.000000
# mean    2017.100464   20788.309968   23526.659706    123.383442     55.443913
# std        2.215099   11605.096412   22172.283833     66.615330     20.038477
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   12990.000000    6445.000000    125.000000     45.600000
# 50%     2017.000000   18750.000000   17467.500000    145.000000     55.000000
# 75%     2019.000000   25950.000000   33737.750000    145.000000     64.200000
# max     2020.000000  159999.000000  323000.000000    580.000000    470.800000
#
#          engineSize        Diesel      Electric        Hybrid         Other  \
# count  46166.000000  46166.000000  46166.000000  46166.000000  46166.000000
# mean       1.909262      0.517740      0.000065      0.062622      0.003227
# std        0.604635      0.499691      0.008061      0.242284      0.056720
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.500000      0.000000      0.000000      0.000000      0.000000
# 50%        2.000000      1.000000      0.000000      0.000000      0.000000
# 75%        2.000000      1.000000      0.000000      0.000000      0.000000
# max        6.600000      1.000000      1.000000      1.000000      1.000000
#
#              Petrol     Automatic        Manual       Other.1     Semi-Auto  \
# count  46166.000000  46166.000000  46166.000000  46166.000000  46166.000000
# mean       0.416345      0.312936      0.341745      0.000108      0.345211
# std        0.492958      0.463694      0.474300      0.010407      0.475442
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        1.000000      1.000000      1.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                Audi           BMW       Hyundai      Mercedes        Toyota
# count  46166.000000  46166.000000  46166.000000  46166.000000  46166.000000
# mean       0.231079      0.233527      0.105272      0.284170      0.145952
# std        0.421527      0.423079      0.306907      0.451023      0.353061
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000

# %%
df.isnull().sum()
# Out:
# model         0
# year          0
# price         0
# mileage       0
# tax           0
# mpg           0
# engineSize    0
# Diesel        0
# Electric      0
# Hybrid        0
# Other         0
# Petrol        0
# Automatic     0
# Manual        0
# Other.1       0
# Semi-Auto     0
# Audi          0
# BMW           0
# Hyundai       0
# Mercedes      0
# Toyota        0
# dtype: int64

# %%
df_new = df.drop(columns=["Other","Other.1"])

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.duplicated().value_counts()
# Out:
# False    45562
# True       604
# dtype: int64

# %%
# check the count of the unique value of each categorical variable
# Making a list of all catrgorical variables
cat_col = list(df_new.select_dtypes("object").columns)

# Printing number of count of each unique value in each column
for column in cat_col:
    print(df_new[column].value_counts())
    print("-" * 50)
    print(f"We have {df_new[column].nunique()} type of models")
# Out:
# C Class     3747
# A Class     2561
# 3 Series    2443
# Yaris       2122
# 1 Series    1969
#             ...
# RS7            1
# A2             1
# 200            1
# Accent         1
# Amica          1
# Name: model, Length: 111, dtype: int64
# --------------------------------------------------
# We have 111 type of models

# %% [markdown]
# ##### Univarite Analysis

# %%
def histogram_boxplot(dataframe, feature, figsize=(15, 10), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (15,10))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a triangle will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# Observation on Engine Size
histogram_boxplot(dataframe=df_new, feature="engineSize" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-61437ecacbb3> in <module>
#       1 # Observation on Engine Size
# ----> 2 histogram_boxplot(dataframe=df_new, feature="engineSize" )
#
# <ipython-input-16-d98629286d01> in histogram_boxplot(dataframe, feature, figsize, kde, bins)
#      16     )  # creating the 2 subplots
#      17     sns.boxplot(
# ---> 18         data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
#      19     )  # boxplot will be created and a triangle will indicate the mean value of the column
#      20     sns.histplot(
#
# NameError: name 'data' is not defined

# %%
# Observation on Year
histogram_boxplot(df_new, "year" )

# %%
# Observation on Engine Size
histogram_boxplot(df_new, "price" )

# %%
# Observation on Engine Size
histogram_boxplot(df_new, "mileage" )

# %%
# Observation on Engine Size
histogram_boxplot(df_new, "tax" )

# %%
# Observation on Engine Size
histogram_boxplot(df_new, "mpg" )

# %% [markdown]
# ###### Bivarite Analysis

# %%
cols_list = df_new.select_dtypes(include=np.number).columns.tolist()

plt.figure(figsize=(12, 7))
sns.heatmap(
    df_new[cols_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral"
)
plt.show()

# %%
### function to plot distributions wrt target


def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
        stat="density",
    )

    axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
        stat="density",
    )

    axs[1, 0].set_title("Boxplot w.r.t target")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %%
distribution_plot_wrt_target(df_new, "engineSize", "price")
